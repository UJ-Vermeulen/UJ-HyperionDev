# %% [markdown]
# # Practical Task 2

# %% [markdown]
# # Import the necessary Libraries

# %%
# Import necessary libraries
# After doing research, the r2_score import was found (on stacks overflow)
# to be an appropriate way to calculate the R^2 value
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import r2_score

# %% [markdown]
# # Load the Dataset

# %%
# Load the dataset
data = pd.read_csv('diabetes_dirty.csv')

# %% [markdown]
# # Differentiate between the dependent and independent variables

# %%
# The dependent variable is PROGRESSION
X = data.drop(columns=['PROGRESSION'])
Y = data['PROGRESSION']

# %% [markdown]
# # Split the data into training and test sets

# %%
# Training and Test sets
X_train, X_test, Y_train, Y_test = train_test_split(X,
                    Y, test_size=0.2, random_state=42)

# %% [markdown]
# # Normalise the data and fit scalers on training set

# %%
# Normalise the data using MinMaxScaler and StandardScaler
scaler_min_max = MinMaxScaler()
scaler_standard = StandardScaler()

# Fit the scalers on the training set and transform both training 
# And test sets
X_train_min_max = scaler_min_max.fit_transform(X_train)
X_test_min_max = scaler_min_max.transform(X_test)

X_train_standard = scaler_standard.fit_transform(X_train)
X_test_standard = scaler_standard.transform(X_test)

# %% [markdown]
# # Fit multiple linear regression model using the training set

# %%
# Make a multiple linear regression model using the training set
model = LinearRegression()
model.fit(X_train_standard, Y_train)

# %% [markdown]
# # Print the model's intercept and coefficient values

# %%
# Print out the intercept and coefficients of the trained model
print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)
# Out:
# Intercept: 153.7365439093484
# Coefficients: [  1.75375799 -11.51180908  25.60712144  16.82887167 -44.44885564
#   24.64095356   7.67697768  13.1387839   35.16119521   2.35136365]

# %% [markdown]
# # Predictions and R-value for Test Set

# %%
# Generate predictions for the test set
Y_pred = model.predict(X_test_standard)

# Compute R-squared for the model on the test set
r2 = r2_score(Y_test, Y_pred)
print("R-squared:", r2)
# Out:
# R-squared: 0.45260276297191915

# %% [markdown]
# # Conclusion and Notes

# %% [markdown]
# An R value of 0.452 means that 45.2% of the variance in the dependent variable is explained by the regression model. Which shows the model is a 'moderate' fit.
