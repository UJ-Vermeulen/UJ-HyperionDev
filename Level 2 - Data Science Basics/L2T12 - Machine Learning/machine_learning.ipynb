# %% [markdown]
# # Machine Learning
# ## Compulsory task

# %% [markdown]
# 1. For each of the following examples describe at least one possible input and
# output. Justify your answers:
# * 1.1 A self-driving car
# * 1.2 Netflix recommendation system
# * 1.3 Signature recognition
# * 1.4 Medical diagnosis

# %% [markdown]
# 1. Answer here
#
# |      | Input(s)    | Output     | Reason      |
# | ---- | ----------- | ---------  | --------    |
# | 1.1  | sensor data such as 360 degree cameras           | steering commands            | The car could use surrounding cameras to determine if route is safe and to keep a safe distance using steering commands            |
# | 1.2  | using user viewing history to determine preferences            | recommend movies           | Allows predicting which movies or shows the user might like and enjoy          |
# | 1.3  | a picture of the handwritten signature to compare it to             |  legitimacy tests          | The image would be processed and compared to the input signature and determine legitimacy and authenticity            |
# | 1.4  | patient symptoms and medical history             | diagnosis           | the system would determine possible medical conditions based on symptoms and patient data            |

# %% [markdown]
# 2. For each of the following case studies, determine whether it is appropriate to utilise regression or classification machine learning algorithms. Justify your answers:
# * 2.1 Classifying emails as promotion or social based on their content and metadata.
# * 2.2 Forecasting the stock price of a company based on historical data and market trends.
# * 2.3 Sorting images of animals into different species based on their visual features.
# * 2.4 Predicting the likelihood of a patient having a particular disease based on medical history and diagnostic test results.

# %% [markdown]
# 2. Answer here
# * 2.1 Classification: This involves categorising emails into either 'social' or 'promotional'
# * 2.2 Regression: This required predicting continuous stock prices based on the input features
# * 2.3 Classification: This involves categorising imagines of animals into distinct classes (species)
# * 2.4 Classification: This is to predict whether a disease is present or absent

# %% [markdown]
# 3. For each of the following real-world problems, determine whether it is appropriate to utilise a supervised or unsupervised machine learning algorithm. Justify your answers:
# * 3.1 Detecting anomalies in a manufacturing process using sensor data without prior knowledge of specific anomaly patterns.
# * 3.2 Predicting customer lifetime value based on historical transaction data and customer demographics.
# * 3.3 Segmenting customer demographics based on their purchase history, browsing behaviour, and preferences.
# * 3.4 Analysing social media posts to categorise them into different themes.

# %% [markdown]
# 3. Answer here
# * 3.1 Unsupervised: It involves finding patterns in unlabeled data and no predefined categories
# * 3.2 Supervised: This requires predicting a continuous outcome based on defined historical data
# * 3.3 Unsupervised: Customer grouping without predefined labels
# * 3.4 Supervised: If the user's post is labelled with a theme, it means they are classified into those categories

# %% [markdown]
# 4.
# For each of the following real-world problems, determine whether it is appropriate to utilise semi-supervised machine learning algorithms. Justify your answers:
# * 4.1 Predicting fraudulent financial transactions using a dataset where most transactions are labelled as fraudulent or legitimate.
# * 4.2 Analysing customer satisfaction surveys where only a small portion of the data is labelled with satisfaction ratings.
# * 4.3 Identifying spam emails in a dataset where the majority of emails are labelled.
# * 4.4 Predicting the probability of default for credit card applicants based on their complete financial and credit-related information.

# %% [markdown]
# 4. Answer here
# * 4.1 Yes: The large amount of labelled data could be 'complemented' with unlabelled data to improve model performance
# * 4.2 Yes: Semi-supervised learning can leverage the small labeled dataset along with a much larger unlabelled dataset to improve and enhance future predictions
# * 4.3 Yes: The algorithm could use labelled data (not-spam) to learn and apply what it learned to unlabelled emails, which could them improve spam detection.
# * 4.4 No: If all of the data is already labelled, then there is no need for any semi-supervised learning.
